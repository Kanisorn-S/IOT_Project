# %% [markdown]
# # 1. Import Libraries

# %%
import tensorflow as tf
import os 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')

# %%
import os
import cv2
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from termcolor import colored
import matplotlib.pyplot as plt
from keras.utils import plot_model
from tensorflow.keras import optimizers
from tensorflow.keras import models, layers
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix

# %%
sns.set_style('darkgrid')
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Data

# %% [markdown]
# ## 2.1. Import Data

# %%
base_dir = '../data'

# %%
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %% [markdown]
# ## 2.2. Count data and classes

# %%
def num_of_classes(folder_dir, folder_name) :
    classes = [class_name for class_name in os.listdir(train_dir)]
    print(colored(f'number of classes in {folder_name} folder : {len(classes)}', 'blue', attrs=['bold']))

# %%
num_of_classes(train_dir, 'train')
num_of_classes(validation_dir, 'validation')
num_of_classes(test_dir, 'test')
# Out:
# number of classes in train folder : 36
# number of classes in validation folder : 36
# number of classes in test folder : 36

# %%
classes = [class_name for class_name in os.listdir(train_dir)]
count = []
for class_name in classes :
    count.append(len(os.listdir(os.path.join(train_dir, class_name))))

plt.figure(figsize=(15, 4))
ax = sns.barplot(x=classes, y=count, color='navy')
plt.xticks(rotation=285)
for i in ax.containers:
    ax.bar_label(i,)
plt.title('Number of samples per label', fontsize=25, fontweight='bold')
plt.xlabel('Labels', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.yticks(np.arange(0, 105, 10))
plt.show()

# %% [markdown]
# ## 2.3 Convert data to a dataframe

# %%
# A function to return DataFrame

def create_df(folder_path) :
    all_images = []    
    for class_name in classes :
        class_path = os.path.join(folder_path, class_name)
        all_images.extend([(os.path.join(class_path, file_name), class_name) for file_name in os.listdir(class_path)])
    df = pd.DataFrame(all_images, columns=['file_path', 'label'])
    return df

# %%
train_df = create_df(train_dir)
validation_df = create_df(validation_dir)
test_df = create_df(test_dir)

# %%
print(colored(f'Number of samples in train : {len(train_df)}', 'blue', attrs=['bold']))
print(colored(f'Number of samples in validation : {len(validation_df)}', 'blue', attrs=['bold']))
print(colored(f'Number of samples test : {len(test_df)}', 'blue', attrs=['bold']))
# Out:
# Number of samples in train : 3115
# Number of samples in validation : 351
# Number of samples test : 359

# %% [markdown]
# ## 2.4 Visualize each class(label)

# %%
# Create a DataFrame with one Label of each category
df_unique = train_df.copy().drop_duplicates(subset=["label"]).reset_index()

# Display some pictures of the dataset
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(8, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.file_path[i]))
    ax.set_title(df_unique.label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

# %% [markdown]
# ## 2.5 Data generators

# %% [markdown]
# Because of having less samples in each category, we use data generator and data augmentation to avoid over fitting and acheive better performance

# %%
# Train generator

train_datagen = ImageDataGenerator(
    rescale=1./255,                 # Scaled images in range 0 to 1
    rotation_range=20,              # Rorate images by factor 20 degree
    width_shift_range=0.2,          # Shift images horizontally by up to 20% of their width
    height_shift_range=0.2,         # Shift images vertically by up to 20% of their width
    zoom_range=0.1,                 # Zoom in and out images by 10%
    horizontal_flip=True,           # Allow horizontal flipping
    shear_range=0.1,                # shear images by 10% their size
    fill_mode='nearest',            # fill unlocated pixels by nearest pixel
    )

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,             # Target data
    x_col='file_path',              # X column
    y_col='label',                  # y column
    target_size=(224, 224),         # Resize images  to
    color_mode='rgb',               # Color mode
    class_mode='categorical',       # type of model
    batch_size=32,                  
    shuffle=True,
    seed=42,
    
)
# Out:
# Found 3115 validated image filenames belonging to 36 classes.

# %%
# validation generator

validation_datagen = ImageDataGenerator(rescale=1./255,)

validation_generator = validation_datagen.flow_from_dataframe(
    dataframe=validation_df,
    x_col='file_path',
    y_col='label',
    target_size=(224, 224),
    class_mode='categorical',
    batch_size=32,
    seed=42,
    shuffle=False
)
# Out:
# Found 351 validated image filenames belonging to 36 classes.

# %%
# Test generator

test_datagen = ImageDataGenerator(rescale=1./255,)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='file_path',
    y_col='label',
    target_size=(224, 224),
    class_mode='categorical',
    batch_size=32,
    seed=42,
    shuffle=False
)
# Out:
# Found 359 validated image filenames belonging to 36 classes.

# %% [markdown]
# # 3. Modelling

# %% [markdown]
# ## 3.1 Add MobileNetV2 model

# %%
from tensorflow.keras.applications import MobileNetV2

# Option 1: Use local weights if available
pre_trained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights= 'imagenet',
    pooling='avg'
)

# %% [markdown]
# ## 3.2 Freeze MobileNetV2 layers

# %%
# Name of layers in MobileNetV2
for layer in pre_trained_model.layers :
    print(layer.name)
# Out:
# input_layer
# Conv1
# bn_Conv1
# Conv1_relu
# expanded_conv_depthwise
# expanded_conv_depthwise_BN
# expanded_conv_depthwise_relu
# expanded_conv_project
# expanded_conv_project_BN
# block_1_expand
# block_1_expand_BN
# block_1_expand_relu
# block_1_pad
# block_1_depthwise
# block_1_depthwise_BN
# block_1_depthwise_relu
# block_1_project
# block_1_project_BN
# block_2_expand
# block_2_expand_BN
# block_2_expand_relu
# block_2_depthwise
# block_2_depthwise_BN
# block_2_depthwise_relu
# block_2_project
# block_2_project_BN
# block_2_add
# block_3_expand
# block_3_expand_BN
# block_3_expand_relu
# block_3_pad
# block_3_depthwise
# block_3_depthwise_BN
# block_3_depthwise_relu
# block_3_project
# block_3_project_BN
# block_4_expand
# block_4_expand_BN
# block_4_expand_relu
# block_4_depthwise
# block_4_depthwise_BN
# block_4_depthwise_relu
# block_4_project
# block_4_project_BN
# block_4_add
# block_5_expand
# block_5_expand_BN
# block_5_expand_relu
# block_5_depthwise
# block_5_depthwise_BN
# block_5_depthwise_relu
# block_5_project
# block_5_project_BN
# block_5_add
# block_6_expand
# block_6_expand_BN
# block_6_expand_relu
# block_6_pad
# block_6_depthwise
# block_6_depthwise_BN
# block_6_depthwise_relu
# block_6_project
# block_6_project_BN
# block_7_expand
# block_7_expand_BN
# block_7_expand_relu
# block_7_depthwise
# block_7_depthwise_BN
# block_7_depthwise_relu
# block_7_project
# block_7_project_BN
# block_7_add
# block_8_expand
# block_8_expand_BN
# block_8_expand_relu
# block_8_depthwise
# block_8_depthwise_BN
# block_8_depthwise_relu
# block_8_project
# block_8_project_BN
# block_8_add
# block_9_expand
# block_9_expand_BN
# block_9_expand_relu
# block_9_depthwise
# block_9_depthwise_BN
# block_9_depthwise_relu
# block_9_project
# block_9_project_BN
# block_9_add
# block_10_expand
# block_10_expand_BN
# block_10_expand_relu
# block_10_depthwise
# block_10_depthwise_BN
# block_10_depthwise_relu
# block_10_project
# block_10_project_BN
# block_11_expand
# block_11_expand_BN
# block_11_expand_relu
# block_11_depthwise
# block_11_depthwise_BN
# block_11_depthwise_relu
# block_11_project
# block_11_project_BN
# block_11_add
# block_12_expand
# block_12_expand_BN
# block_12_expand_relu
# block_12_depthwise
# block_12_depthwise_BN
# block_12_depthwise_relu
# block_12_project
# block_12_project_BN
# block_12_add
# block_13_expand
# block_13_expand_BN
# block_13_expand_relu
# block_13_pad
# block_13_depthwise
# block_13_depthwise_BN
# block_13_depthwise_relu
# block_13_project
# block_13_project_BN
# block_14_expand
# block_14_expand_BN
# block_14_expand_relu
# block_14_depthwise
# block_14_depthwise_BN
# block_14_depthwise_relu
# block_14_project
# block_14_project_BN
# block_14_add
# block_15_expand
# block_15_expand_BN
# block_15_expand_relu
# block_15_depthwise
# block_15_depthwise_BN
# block_15_depthwise_relu
# block_15_project
# block_15_project_BN
# block_15_add
# block_16_expand
# block_16_expand_BN
# block_16_expand_relu
# block_16_depthwise
# block_16_depthwise_BN
# block_16_depthwise_relu
# block_16_project
# block_16_project_BN
# Conv_1
# Conv_1_bn
# out_relu
# global_average_pooling2d

# %%
# Freeze all layers, except last layer
# The goal is to train just last layer of pre trained model

pre_trained_model.trainable = True
set_trainable = False

for layer in pre_trained_model.layers :
    if layer.name == 'block_16_expand' :
        set_trainable = True
    if set_trainable :
        layer.trainable = True
    else :
        layer.trainable = False

# %% [markdown]
# ## 3.3 Define a model

# %%
# Add custom layers on top of the base model
model = models.Sequential()
model.add(pre_trained_model)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(36, activation='softmax'))

# %% [markdown]
# ## 3.4 Model Diagram

# %%
plot_model(model, show_shapes=True, show_layer_names=False, dpi=200)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 36)             │         4,644 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,623,460 (10.01 MB)
#  Trainable params: 1,251,556 (4.77 MB)
#  Non-trainable params: 1,371,904 (5.23 MB)

# %% [markdown]
# ## 3.5 Compile Model

# %%
# Compile 
model.compile(optimizer=optimizers.Adam(learning_rate=0.001),
             loss='categorical_crossentropy', 
             metrics=['accuracy'])

# %% [markdown]
# ## 3.6 Callbacks

# %%
# Model CheckPoint
checkpoint_cb = ModelCheckpoint('MyModel.keras', save_best_only=True) 

# Early Stoping
earlystop_cb = EarlyStopping(patience=10, restore_best_weights=True)

# ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# %% [markdown]
# ## 3.7 Train Model

# %%
# %pip install keras==3.6.0 -i https://pypi.python.org/simple
# Out:
# Looking in indexes: https://pypi.python.org/simple
# Requirement already satisfied: keras==3.6.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (3.6.0)
# Requirement already satisfied: absl-py in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras==3.6.0) (2.1.0)
# Requirement already satisfied: numpy in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras==3.6.0) (2.0.2)
# Requirement already satisfied: rich in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras==3.6.0) (13.9.4)
# Requirement already satisfied: namex in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras==3.6.0) (0.0.8)
# Requirement already satisfied: h5py in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras==3.6.0) (3.12.1)
# Requirement already satisfied: optree in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras==3.6.0) (0.13.0)
# Requirement already satisfied: ml-dtypes in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras==3.6.0) (0.4.1)
# Requirement already satisfied: packaging in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras==3.6.0) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from optree->keras==3.6.0) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from rich->keras==3.6.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from rich->keras==3.6.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras==3.6.0) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflow==2.18.0
# Out:
# Requirement already satisfied: tensorflow==2.18.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow==2.18.0) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (75.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (1.67.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.44.0)
# Requirement already satisfied: rich in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (13.9.4)
# Requirement already satisfied: namex in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.0.8)
# Requirement already satisfied: optree in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\acer\desktop\iot\iot_project\raspberrypi\venv2\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
from PIL import Image
sys.modules['Image'] = Image

# %%
from PIL import Image
print(Image.__file__)
# Out:
# c:\Users\acer\Desktop\iot\IOT_Project\RaspberryPi\venv2\Lib\site-packages\PIL\Image.py

# %%
import Image
print(Image.__file__)
# Out:
# c:\Users\acer\Desktop\iot\IOT_Project\RaspberryPi\venv2\Lib\site-packages\PIL\Image.py

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=30,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr]
)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.4404 - loss: 2.1672 - val_accuracy: 0.6382 - val_loss: 2.2787 - learning_rate: 0.0010
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.7467 - loss: 0.8068 - val_accuracy: 0.7635 - val_loss: 1.2746 - learning_rate: 0.0010
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.8039 - loss: 0.6075 - val_accuracy: 0.8405 - val_loss: 0.7139 - learning_rate: 0.0010
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8483 - loss: 0.4609 - val_accuracy: 0.7635 - val_loss: 1.3388 - learning_rate: 0.0010
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8571 - loss: 0.4339 - val_accuracy: 0.7664 - val_loss: 1.1181 - learning_rate: 0.0010
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8570 - loss: 0.3922 - val_accuracy: 0.8462 - val_loss: 0.8683 - learning_rate: 0.0010
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9170 - loss: 0.2612 - val_accuracy: 0.8547 - val_loss: 0.7078 - learning_rate: 5.0000e-04
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9392 - loss: 0.1737 - val_accuracy: 0.9088 - val_loss: 0.4409 - learning_rate: 5.0000e-04
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9321 - loss: 0.1734 - val_accuracy: 0.9259 - val_loss: 0.3237 - learning_rate: 5.0000e-04
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.9499 - loss: 0.1444 - val_accuracy: 0.9174 - val_loss: 0.3544 - learning_rate: 5.0000e-04
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9523 - loss: 0.1357 - val_accuracy: 0.9202 - val_loss: 0.4671 - learning_rate: 5.0000e-04
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9502 - loss: 0.1373 - val_accuracy: 0.9402 - val_loss: 0.3587 - learning_rate: 5.0000e-04
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9520 - loss: 0.1358 - val_accuracy: 0.9516 - val_loss: 0.2168 - learning_rate: 2.5000e-04
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.9716 - loss: 0.0809 - val_accuracy: 0.9544 - val_loss: 0.1762 - learning_rate: 2.5000e-04
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.9692 - loss: 0.0844 - val_accuracy: 0.9544 - val_loss: 0.1710 - learning_rate: 2.5000e-04
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04

# %% [markdown]
# ## 3.8 Plot the result of the training

# %%
history.history['val_accuracy'] = [0 for i in range(30)]
history.history['val_loss'] = [0 for i in range(30)]

# %%
# Convert resutl of training to a DataFrame
result_df = pd.DataFrame(history.history)
result_df.tail()
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 25  0.000000  0.000000             0         0        0.00025
# 26  0.969823  0.079020             0         0        0.00025
# 27  0.000000  0.000000             0         0        0.00025
# 28  0.967576  0.085919             0         0        0.00025
# 29  0.000000  0.000000             0         0        0.00025

# %%
x = np.arange(len(result_df))
fig, ax = plt.subplots(3, 1, figsize=(15, 12))
#  AX0 : Loss
ax[0].plot(x, result_df.loss, label='loss', linewidth=3)
ax[0].plot(x, result_df.val_loss, label='val_loss', linewidth=2, ls='-.', c='r')
ax[0].set_title('Loss', fontsize=20)
ax[0].legend()

#  AX1 : Loss
ax[1].plot(x, result_df.accuracy, label='accuracy', linewidth=2)
ax[1].plot(x, result_df.val_accuracy, label='val_accuracy', linewidth=2, ls='-.', c='r')
ax[1].set_title('Accuracy', fontsize=20)
ax[1].legend()

#  AX2 : Loss
ax[2].plot(x, result_df.lr, label='learning_rate', linewidth=2)
ax[2].set_title('learning_rate', fontsize=20)
ax[2].set_xlabel('epochs')
ax[2].legend()


plt.sharex=True


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_115856\3783768206.py in ?()
#      12 ax[1].set_title('Accuracy', fontsize=20)
#      13 ax[1].legend()
#      14
#      15 #  AX2 : Loss
# ---> 16 ax[2].plot(x, result_df.lr, label='learning_rate', linewidth=2)
#      17 ax[2].set_title('learning_rate', fontsize=20)
#      18 ax[2].set_xlabel('epochs')
#      19 ax[2].legend()
#
# c:\Users\acer\Desktop\iot\IOT_Project\RaspberryPi\venv2\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'lr'

# %% [markdown]
# ## 3.9 Evaluate the Model

# %%
# checkpoint callback, save base model weights in "MyModel.keras".
# So, we should load it
best_model = models.load_model('MyModel.keras')

# %%
def evaluate_model_performance(model, val_generator, class_labels):
    """
    Evaluate the model's performance on the validation set and print the classification report.

    Parameters:
    - model: The trained model.
    - val_generator: Validation data generator.
    - class_labels: List of class names.
    
    Returns:
    - report: Classification report as a string.
    """
    
    # Getting all the true labels for the validation set
    true_labels = val_generator.classes

    # Get the class labels (names) from the generator
    class_labels = list(val_generator.class_indices.keys())

    # To get the predicted labels, we predict using the model  
    predictions = model.predict(val_generator, steps=len(val_generator))
    
    # Take the argmax to get the predicted class indices.
    predicted_labels = np.argmax(predictions, axis=1)
    
    # Extracting true labels from the validation generator
    true_labels = val_generator.classes

    # Classification report
    report = classification_report(true_labels, predicted_labels, target_names=class_labels)
    print(report)
    print('\n')
    
    # Define a custom colormap
    colors = ["white", "#102C42"]
    # cmap_cm = LinearSegmentedColormap.from_list("cmap_cm", colors)

    # Confusion Matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    # Plotting confusion matrix using seaborn
    plt.figure(figsize=(15,10))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels, cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

# %%
evaluate_model_performance(best_model, validation_generator, classes)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step
#                precision    recall  f1-score   support
#
#         apple       0.82      0.90      0.86        10
#        banana       1.00      0.78      0.88         9
#      beetroot       1.00      1.00      1.00        10
#   bell pepper       0.64      1.00      0.78         9
#       cabbage       1.00      1.00      1.00        10
#      capsicum       1.00      0.60      0.75        10
#        carrot       1.00      1.00      1.00         9
#   cauliflower       1.00      1.00      1.00        10
# chilli pepper       0.90      1.00      0.95         9
#          corn       0.88      0.70      0.78        10
#      cucumber       1.00      1.00      1.00        10
#      eggplant       1.00      1.00      1.00        10
#        garlic       1.00      1.00      1.00        10
#        ginger       1.00      1.00      1.00        10
#        grapes       1.00      1.00      1.00         9
#      jalepeno       1.00      0.89      0.94         9
#          kiwi       1.00      1.00      1.00        10
#         lemon       0.83      1.00      0.91        10
#       lettuce       1.00      1.00      1.00         9
#         mango       1.00      1.00      1.00        10
#         onion       1.00      1.00      1.00        10
#        orange       1.00      0.78      0.88         9
#       paprika       0.91      1.00      0.95        10
#          pear       1.00      1.00      1.00        10
#          peas       1.00      1.00      1.00        10
#     pineapple       1.00      1.00      1.00        10
#   pomegranate       1.00      1.00      1.00        10
#        potato       0.90      0.90      0.90        10
#       raddish       1.00      1.00      1.00         9
#     soy beans       1.00      1.00      1.00        10
#       spinach       1.00      1.00      1.00        10
#     sweetcorn       0.75      0.90      0.82        10
#   sweetpotato       1.00      0.90      0.95        10
#        tomato       1.00      1.00      1.00        10
#        turnip       1.00      1.00      1.00        10
#    watermelon       1.00      1.00      1.00        10
#
#      accuracy                           0.95       351
#     macro avg       0.96      0.95      0.95       351
#  weighted avg       0.96      0.95      0.95       351
